# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### Loading the dataset

# %%
df = pd.read_csv('loan_approval_dataset.csv')

# %% [markdown]
# #### Data Exploration

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  ...  luxury_assets_value   bank_asset_value   loan_status
# 0        1                  2       Graduate  ...             22700000            8000000      Approved
# 1        2                  0   Not Graduate  ...              8800000            3300000      Rejected
# 2        3                  3       Graduate  ...             33300000           12800000      Rejected
# 3        4                  3       Graduate  ...             23300000            7900000      Rejected
# 4        5                  5   Not Graduate  ...             29400000            5000000      Rejected
#
# [5 rows x 13 columns]

# %%
df.columns = df.columns.str.strip()

# %%
df.isna().sum()
# Out:
# loan_id                     0
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.describe()
# Out:
#            loan_id  no_of_dependents  income_annum  ...  commercial_assets_value  luxury_assets_value  bank_asset_value
# count  4269.000000       4269.000000  4.269000e+03  ...             4.269000e+03         4.269000e+03      4.269000e+03
# mean   2135.000000          2.498712  5.059124e+06  ...             4.973155e+06         1.512631e+07      4.976692e+06
# std    1232.498479          1.695910  2.806840e+06  ...             4.388966e+06         9.103754e+06      3.250185e+06
# min       1.000000          0.000000  2.000000e+05  ...             0.000000e+00         3.000000e+05      0.000000e+00
# 25%    1068.000000          1.000000  2.700000e+06  ...             1.300000e+06         7.500000e+06      2.300000e+06
# 50%    2135.000000          3.000000  5.100000e+06  ...             3.700000e+06         1.460000e+07      4.600000e+06
# 75%    3202.000000          4.000000  7.500000e+06  ...             7.600000e+06         2.170000e+07      7.100000e+06
# ...

# %%
df.loan_status.unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df.loan_status.value_counts()
# Out:
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df.education.unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %% [markdown]
# #### Data Preprocessing

# %%
df.drop('loan_id',axis=1,inplace=True)

# %%
df.education = df.education.str.strip()

# %%
df.loan_status = df.loan_status.str.strip()

# %%
df['education'] = df.education.apply(lambda x : 1 if x == 'Graduate' else 0)
df['self_employed'] = df.self_employed.apply(lambda x : 1 if x == 'Yes' else 0)
df['loan_status'] = df.loan_status.apply(lambda x : 1 if x == 'Approved' else 0)

# %%
df
# Out:
#       no_of_dependents  education  self_employed  ...  luxury_assets_value  bank_asset_value  loan_status
# 0                    2          0              0  ...             22700000           8000000            1
# 1                    0          0              0  ...              8800000           3300000            0
# 2                    3          0              0  ...             33300000          12800000            0
# 3                    3          0              0  ...             23300000           7900000            0
# 4                    5          0              0  ...             29400000           5000000            0
# ...                ...        ...            ...  ...                  ...               ...          ...
# 4264                 5          0              0  ...              3300000            800000            0
# 4265                 0          0              0  ...             11000000           1900000            1
# ...

# %%
df.loan_status.value_counts()
# Out:
# loan_status
# 1    2656
# 0    1613
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                           no_of_dependents  education  ...  bank_asset_value  loan_status
# no_of_dependents                  1.000000        NaN  ...          0.011163    -0.018114
# education                              NaN        NaN  ...               NaN          NaN
# self_employed                          NaN        NaN  ...               NaN          NaN
# income_annum                      0.007266        NaN  ...          0.851093    -0.015189
# loan_amount                      -0.003366        NaN  ...          0.788122     0.016150
# loan_term                        -0.020111        NaN  ...          0.017177    -0.113036
# cibil_score                      -0.009998        NaN  ...         -0.015478     0.770518
# residential_assets_value          0.007376        NaN  ...          0.527418    -0.014367
# commercial_assets_value          -0.001531        NaN  ...          0.548576     0.008246
# ...

# %%
X = df.drop('loan_status', axis=1)
y = df.loan_status

# %% [markdown]
# #### Applying Standard Scalar on Features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #### Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.20, random_state=42)

# %% [markdown]
# #### Model Arhitecture

# %%
model = Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(2, activation='softmax')
])

# %% [markdown]
# #### Compiling the Model

# %%
model.compile(
    optimizer='rmsprop',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# #### Training the Model on training data

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8275 - loss: 0.5304
# Epoch 2/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9315 - loss: 0.2307
# Epoch 3/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9338 - loss: 0.1811
# Epoch 4/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9397 - loss: 0.1634
# Epoch 5/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9467 - loss: 0.1493
# Epoch 6/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9490 - loss: 0.1392
# Epoch 7/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9508 - loss: 0.1312
# Epoch 8/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9537 - loss: 0.1243
# Epoch 9/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9578 - loss: 0.1177
# Epoch 10/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9613 - loss: 0.1124
# Epoch 11/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9628 - loss: 0.1068
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │           1,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              18 │
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9707 - loss: 0.0898
# [0.089779794216156, 0.9707260131835938]

# %%
def predict_loan_status(no_of_dependents, education, self_employed, income_annum,
                        loan_amount, loan_term, cibil_score, residential_assets_value,
                        commercial_assets_value, luxury_assets_value, bank_asset_value):
    
    education = 1 if education.strip().capitalize() == 'Graduate' else 0
    self_employed = 1 if self_employed.strip().capitalize() == 'Yes' else 0
    
    features = np.array([[no_of_dependents, education, self_employed, income_annum,
                          loan_amount, loan_term, cibil_score, residential_assets_value,
                          commercial_assets_value, luxury_assets_value, bank_asset_value]])
    
    features_scaled = scaler.transform(features)
    
    prediction = model.predict(features_scaled)
    predicted_class = prediction.argmax(axis=1)[0]
    confidence = prediction[0][predicted_class]
    
    if predicted_class == 1:
        print(f'Loan Approved — Confidence: {confidence*100:.2f}%')
    else:
        print(f'Loan Rejected — Confidence: {confidence*100:.2f}%')

# %%
no_of_dependents          = int(input('Enter number of dependents: '))
education                 = input('Education (Graduate/Not Graduate): ')
self_employed             = input('Self Employed (Yes/No): ')
income_annum              = int(input('Enter annual income: '))
loan_amount               = int(input('Enter loan amount: '))
loan_term                 = int(input('Enter loan term (years): '))
cibil_score               = int(input('Enter CIBIL score (300-900): '))
residential_assets_value  = int(input('Enter residential assets value: '))
commercial_assets_value   = int(input('Enter commercial assets value: '))
luxury_assets_value       = int(input('Enter luxury assets value: '))
bank_asset_value          = int(input('Enter bank asset value: '))

predict_loan_status(no_of_dependents, education, self_employed, income_annum,
                    loan_amount, loan_term, cibil_score, residential_assets_value,
                    commercial_assets_value, luxury_assets_value, bank_asset_value)
# Out:
# Enter number of dependents:  0
# Education (Graduate/Not Graduate):  Graduate
# Self Employed (Yes/No):  Yes
# Enter annual income:  1000000
# Enter loan amount:  100
# Enter loan term (years):  1
# Enter CIBIL score (300-900):  500
# Enter residential assets value:  200000
# Enter commercial assets value:  2000000
# Enter luxury assets value:  600000
# Enter bank asset value:  8000000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Loan Rejected — Confidence: 100.00%
